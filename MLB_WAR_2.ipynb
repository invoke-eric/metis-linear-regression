# %% [markdown]
# # Imports and Functions

# %%
import requests
from bs4 import BeautifulSoup as bs
from bs4 import Comment
import pandas as pd
import numpy as np

# %%
def create_player_df(url):
    url = url
    page = requests.get(url).text
    soup = bs(page)
    
    players = soup.find_all(attrs={'data-stat': 'player'})
    
    name_list = []
    for i in players:
        if i.text != 'Name':
            name_list.append(i.text)
    
    name_additional_list =[]
    for i in players:
        try:
            name_additional_list.append(i['data-append-csv'])
        except:
            pass
    
    age_list = []
    age = soup.find_all(attrs={'data-stat': 'age'})
    for i in age:
        if i.text != 'Age':
            age_list.append(i.text)
            
    team_list = []
    team = soup.find_all(attrs={'data-stat': 'team_ID'})
    for i in team:
        if i.text != 'Tm':
            team_list.append(i.text)
            
    
    lg_list = []
    lg = soup.find_all(attrs={'data-stat': 'lg_ID'})
    for i in lg:
        if i.text != 'Lg':
            lg_list.append(i.text)
    
    games_list = []
    games = soup.find_all(attrs={'data-stat': 'G'})
    for i in games:
        if i.text != 'G':
            games_list.append(i.text)
    
    AB_list = []
    AB =  soup.find_all(attrs={'data-stat': 'AB'})
    for i in AB:
        if i.text != 'AB':
            AB_list.append(i.text)
            
    R_list = []
    R = soup.find_all(attrs={'data-stat': 'R'})
    for i in R:
        if i.text != 'R':
            R_list.append(i.text)
            
    H_list = []
    H = soup.find_all(attrs={'data-stat': 'H'})
    for i in H:
        if i.text != 'H':
            H_list.append(i.text)
    
    PA_list = []
    PA = soup.find_all(attrs={'data-stat': 'PA'})
    for i in PA:
        if i.text != 'PA':
            PA_list.append(i.text)
            
    doubles_list = []
    doubles = soup.find_all(attrs={'data-stat': '2B'})
    for i in doubles:
        if i.text != '2B':
            doubles_list.append(i.text)
    
    
    triples_list = []
    triples = soup.find_all(attrs={'data-stat': '3B'})
    for i in triples:
        if i.text != '3B':
            triples_list.append(i.text)
            
    HR_list = []
    HR = soup.find_all(attrs={'data-stat': 'HR'})
    for i in HR:
        if i.text != 'HR':
            HR_list.append(i.text)
    
    RBI_list = []
    RBI = soup.find_all(attrs={'data-stat': 'RBI'})
    for i in RBI:
        if i.text != 'RBI':
            RBI_list.append(i.text)
            
    SB_list = []
    SB = soup.find_all(attrs={'data-stat': 'SB'})
    for i in SB:
        if i.text != 'SB':
            SB_list.append(i.text)
            
    CS_list = []
    CS = soup.find_all(attrs={'data-stat': 'CS'})
    for i in CS:
        if i.text != 'CS':
            CS_list.append(i.text)
    
    BB_list = []
    BB = soup.find_all(attrs={'data-stat': 'BB'})
    for i in BB:
        if i.text != 'BB':
            BB_list.append(i.text)
            
    SO_list = []
    SO = soup.find_all(attrs={'data-stat': 'SO'})
    for i in SO:
        if i.text != 'SO':
            SO_list.append(i.text)
            
    BA_list = []
    BA = soup.find_all(attrs={'data-stat': 'batting_avg'})
    for i in BA:
        if i.text != 'BA':
            BA_list.append(i.text)
    
    OBP_list = []
    OBP = soup.find_all(attrs={'data-stat': 'onbase_perc'})
    for i in OBP:
        if i.text != 'OBP':
            OBP_list.append(i.text)
            
    SLG_list = []
    SLG = soup.find_all(attrs={'data-stat': 'slugging_perc'})
    for i in SLG:
        if i.text != 'SLG':
            SLG_list.append(i.text)
    
    OPS_list = []
    OPS = soup.find_all(attrs={'data-stat': 'onbase_plus_slugging'})
    for i in OPS:
        if i.text != 'OPS':
            OPS_list.append(i.text)
    
    OPSplus_list = []
    OPSplus = soup.find_all(attrs={'data-stat': 'onbase_plus_slugging_plus'})
    for i in OPSplus:
        if i.text != 'OPS+':
            OPSplus_list.append(i.text)
    
    TB_list = []
    TB = soup.find_all(attrs={'data-stat': 'TB'})
    for i in TB:
        if i.text != 'TB':
            TB_list.append(i.text)
    
    GIDP_list = []
    GIDP = soup.find_all(attrs={'data-stat': 'GIDP'})
    for i in GIDP:
        if i.text != 'GDP':
            GIDP_list.append(i.text)
    
    HBP_list = []
    HBP = soup.find_all(attrs={'data-stat': 'HBP'})
    for i in HBP:
        if i.text != 'HBP':
            HBP_list.append(i.text)
            
    SH_list = []
    SH = soup.find_all(attrs={'data-stat': 'SH'})
    for i in SH:
        if i.text != 'SH':
            SH_list.append(i.text)
    
    SF_list = []
    SF = soup.find_all(attrs={'data-stat': 'SF'})
    for i in SF:
        if i.text != 'SF':
            SF_list.append(i.text)
            
    IBB_list = []
    IBB = soup.find_all(attrs={'data-stat': 'IBB'})
    for i in IBB:
        if i.text != 'IBB':
            IBB_list.append(i.text)
    
    zipped = list(zip(name_list, name_additional_list, age_list, team_list, lg_list, PA_list, AB_list, R_list, H_list, doubles_list, triples_list,
                 HR_list, RBI_list, SB_list, CS_list, BB_list, SO_list, BA_list, OBP_list, OPS_list, OPSplus_list,
                 TB_list, GIDP_list, HBP_list, SH_list, SF_list, IBB_list))
    c = ['Name', 'Name-additional', 'Age', 'Tm', 'Lg', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI',
              'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'OPS', 'OPS+', 'TB', 'GIDP', 'HBP', 'SH', 'SF', 'IBB']
    df = pd.DataFrame(zipped, columns=c)
    new_df = df.replace(r'^\s*$', np.nan, regex=True)
    new_df = new_df.dropna()
    convert_dict = {'Name': object,
                'Name-additional': object,
                'Age': int,
                'Tm': object,
                'Lg': object,
                'PA': int,
                'AB': int,
                'R': int,
                'H': int,
                '2B': int,
                '3B': int,
                'HR': int,
                'RBI': int,
                'SB': int,
                'CS': int,
                'BB': int,
                'SO': int,
                'BA': float,
                'OBP': float,
                'OPS': float,
                'OPS+': float,
                'TB': int,
                'GIDP': int,
                'HBP': int,
                'SH': int,
                'SF': int,
                'IBB': int
                }
    # thanks stackoverflow https://stackoverflow.com/questions/63728644/convert-multiple-columns-from-string-to-float-and-int
    new_df = new_df.astype(convert_dict)
    return(new_df)

# %%
def create_WAR_df(url):
    url = url
    page = requests.get(url).text
    soup = bs(page)
    
    players = soup.find_all(attrs={'data-stat': 'player'})
    
    WAR_name_additional_list = []
    for i in players:
        try:
            WAR_name_additional_list.append(i['data-append-csv'])
        except:
            pass
    
    WAR_list = []
    WAR = soup.find_all(attrs={'data-stat': 'WAR'})
    for i in WAR:
        if i.text != 'WAR':
            WAR_list.append(i.text)
    
    WAR_df = pd.DataFrame(list(zip(WAR_list, WAR_name_additional_list)), columns=['WAR', 'Name-additional'])
    new_df = WAR_df.replace(r'^\s*$', np.nan, regex=True) # https://sparkbyexamples.com/pandas/pandas-replace-blank-values-with-nan/
    new_df = new_df.dropna()
    convert_dict = {'WAR': float,
                'Name-additional': object,}
    new_df = new_df.astype(convert_dict)
    return(new_df)

# %%
def add_WAR_df(batting_df, value_df, year):
    batting_df['Year'] = year
    waa_df = value_df[['Name-additional', 'WAR']]
    
    #the Name-additional field is a UID per player to account for different players with the same name
    joined = batting_df.set_index('Name-additional').join(waa_df.set_index('Name-additional'))
    joined = joined.dropna()
    
    #reset the index because the prior index doesn't matter
    joined_new = joined.reset_index()
    joined_new['Name-year'] = joined_new['Name-additional'] + joined_new['Year'].astype(str)
    return(joined_new)

# %%
def create_curr_WAR_df(url):
    url = url
    page = requests.get(url).text
    soup = bs(page)
    
    players = soup.find_all(attrs={'data-stat': 'player'})
    
    WAR_name_additional_list = []
    for i in players:
        try:
            WAR_name_additional_list.append(i['data-append-csv'])
        except:
            pass
    
    WAR_list = []
    WAR = soup.find_all(attrs={'data-stat': 'WAR'})
    for i in WAR:
        if i.text != 'WAR':
            WAR_list.append(i.text)
    
    WAR_df = pd.DataFrame(list(zip(WAR_list, WAR_name_additional_list)), columns=['curr_WAR', 'Name-additional'])
    new_df = WAR_df.replace(r'^\s*$', np.nan, regex=True)
    new_df = new_df.dropna()
    convert_dict = {'curr_WAR': float,
                'Name-additional': object,}
    new_df = new_df.astype(convert_dict)
    return(new_df)

# %%
def add_curr_WAR_df(batting_df, value_df, year):
    batting_df['Year'] = year
    waa_df = value_df[['Name-additional', 'curr_WAR']]
    
    #the Name-additional field is a UID per player to account for different players with the same name
    joined = batting_df.set_index('Name-additional').join(waa_df.set_index('Name-additional'))
    joined = joined.dropna()
    
    #reset the index because the prior index doesn't matter
    joined_new = joined.reset_index()
    joined_new['Name-year'] = joined_new['Name-additional'] + joined_new['Year'].astype(str)
    return(joined_new)

# %%
def deduplicate_dataframe(input_df):
    df = input_df[input_df['PA'] > 120]
    
    #select players who played for multiple teams across NL and AL
    duplicatePlayers = df[(df['Tm'] == 'TOT') & (df['Lg'] == 'MLB')]
    duplicatePlayers = duplicatePlayers.drop_duplicates()  

    duplicate_nl_al = df[(df['Tm'] == 'TOT') & ((df['Lg'] == 'NL') | (df['Lg'] == 'AL'))]
    
    new_df = df.copy()
    new_df['Duplicate1'] = df['Name-additional'].isin(duplicatePlayers['Name-additional'])
    new_df['Duplicate2'] = df['Name-additional'].isin(duplicate_nl_al['Name-additional'])

    
    #drop based on the masks
    dropped=new_df[new_df.Duplicate1 != True]
    dropped2=dropped[dropped.Duplicate2 != True]    
    dropped3 = dropped2.drop(columns=['Duplicate1', 'Duplicate2'])
    
    #Add the duplicate players back in, this time only adding a single row (see the team 'TOT')
    dedup_df = pd.concat([dropped3, duplicate_nl_al, duplicatePlayers])
    dedup_df = dedup_df.dropna() #drop nulls, should be minimal
    dedup_df = dedup_df.drop_duplicates()
    
    return(dedup_df)

# %%
def create_joined_df(batting_url, WAR_url, curr_WAR_url, year):
    batting_df = create_player_df(batting_url)
    WAR_df = create_WAR_df(WAR_url)
    curr_WAR_df = create_curr_WAR_df(curr_WAR_url)
    batting_df_dedup = deduplicate_dataframe(batting_df)
    joined_df = add_WAR_df(batting_df_dedup, WAR_df, year)
    joined_df_2 = add_curr_WAR_df(joined_df, curr_WAR_df, year)
    return(joined_df_2)

# %% [markdown]
# # Create Main DataFrame

# %%
batting_url_list = ['https://www.baseball-reference.com/tools/share.fcgi?id=1q0ji',
                   'https://www.baseball-reference.com/tools/share.fcgi?id=Uk515',
                   'https://www.baseball-reference.com/tools/share.fcgi?id=iKTPD']

WAR_url_list = ['https://www.baseball-reference.com/tools/share.fcgi?id=HZVmu',
                'https://www.baseball-reference.com/tools/share.fcgi?id=HHB2A',
                'https://www.baseball-reference.com/tools/share.fcgi?id=M1xJV']
curr_WAR_list = ['https://www.baseball-reference.com/tools/share.fcgi?id=97CgF',
                'https://www.baseball-reference.com/tools/share.fcgi?id=HZVmu',
                'https://www.baseball-reference.com/tools/share.fcgi?id=M1xJV']

year_list = ['2016', '2017', '2018']

# %%
df_2016 = create_joined_df(batting_url_list[0], WAR_url_list[0], curr_WAR_list[0], year_list[0])
df_2017 = create_joined_df(batting_url_list[1], WAR_url_list[1], curr_WAR_list[1], year_list[1])
df_2018 = create_joined_df(batting_url_list[2], WAR_url_list[2], curr_WAR_list[2], year_list[2])

# %%
df = pd.concat([df_2016, df_2017, df_2018], ignore_index=True)

# %%
df.info()
# note that for our purposes, "WAR" means NEXT SEASON's WAR, while "curr_WAR" means THIS SEASON's WAR
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name-additional  1121 non-null   object
#  1   Name             1121 non-null   object
#  2   Age              1121 non-null   int64
#  3   Tm               1121 non-null   object
#  4   Lg               1121 non-null   object
#  5   PA               1121 non-null   int64
#  6   AB               1121 non-null   int64
#  7   R                1121 non-null   int64
#  8   H                1121 non-null   int64
#  9   2B               1121 non-null   int64
#  10  3B               1121 non-null   int64
#  11  HR               1121 non-null   int64
#  12  RBI              1121 non-null   int64
#  13  SB               1121 non-null   int64
#  14  CS               1121 non-null   int64
#  15  BB               1121 non-null   int64
#  16  SO               1121 non-null   int64
# ...

# %% [markdown]
# #### Trim to only numerics

# %%
new_df = df.drop(columns=['Name-additional', 'Name', 'Tm', 'Lg', 'Name-year'])
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1121 non-null   int64
#  1   PA        1121 non-null   int64
#  2   AB        1121 non-null   int64
#  3   R         1121 non-null   int64
#  4   H         1121 non-null   int64
#  5   2B        1121 non-null   int64
#  6   3B        1121 non-null   int64
#  7   HR        1121 non-null   int64
#  8   RBI       1121 non-null   int64
#  9   SB        1121 non-null   int64
#  10  CS        1121 non-null   int64
#  11  BB        1121 non-null   int64
#  12  SO        1121 non-null   int64
#  13  BA        1121 non-null   float64
#  14  OBP       1121 non-null   float64
#  15  OPS       1121 non-null   float64
#  16  OPS+      1121 non-null   float64
#  17  TB        1121 non-null   int64
#  18  GIDP      1121 non-null   int64
#  19  HBP       1121 non-null   int64
# ...

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.subplots(figsize=(20,15)) #thanks stackexchange https://datascience.stackexchange.com/questions/17540/make-seaborn-heatmap-bigger
sns.heatmap(new_df.corr(), cmap="seismic", annot=True, vmin=-1, vmax=1); # https://www.freecodecamp.org/news/regression-analysis-on-life-expectancy/

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
sns.histplot(new_df.WAR,color='cyan')
plt.title('Histogram of WAR (Next Year)');

# %%
new_df.corr().loc['WAR'].sort_values(ascending=False)
# Out:
# WAR         1.000000
# curr_WAR    0.724780
# R           0.479503
# TB          0.457295
# 2B          0.449232
# H           0.429356
# RBI         0.410888
# PA          0.409562
# BB          0.399936
# OPS         0.399554
# OPS+        0.398463
# AB          0.395127
# HR          0.381353
# OBP         0.345210
# IBB         0.310562
# BA          0.310170
# SO          0.281139
# SB          0.269109
# 3B          0.241491
# SF          0.233667
# CS          0.219562
# GIDP        0.208008
# HBP         0.180541
# SH         -0.063216
# Age        -0.219007
# Name: WAR, dtype: float64

# %%
g=sns.pairplot(new_df,kind="scatter");
g.fig.set_size_inches(15,15)

# %%
new_df.columns
# Out:
# Index(['Age', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB',
#        'SO', 'BA', 'OBP', 'OPS', 'OPS+', 'TB', 'GIDP', 'HBP', 'SH', 'SF',
#        'IBB', 'Year', 'WAR', 'curr_WAR'],
#       dtype='object')

# %%
new_df['Year'] = new_df['Year'].astype('int')

# %%
new_df.dtypes
# Out:
# Age           int64
# PA            int64
# AB            int64
# R             int64
# H             int64
# 2B            int64
# 3B            int64
# HR            int64
# RBI           int64
# SB            int64
# CS            int64
# BB            int64
# SO            int64
# BA          float64
# OBP         float64
# OPS         float64
# OPS+        float64
# TB            int64
# GIDP          int64
# HBP           int64
# SH            int64
# SF            int64
# IBB           int64
# Year          int64
# WAR         float64
# curr_WAR    float64
# dtype: object

# %%
X=new_df.drop(columns=['WAR'],axis=1)
y=new_df['WAR']

Train = new_df[new_df['Year'] == 2016]
Val = new_df[new_df['Year'] == 2017]
Test = new_df[new_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

# %% [markdown]
# ## Initial Linear Model Example

# %%
#naive linear model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)

print('Train R^2: ' + str(lr.score(X_train,y_train)))

print('Val R^2: ' + str(lr.score(X_val,y_val)))
# Out:
# Train R^2: 0.3882580003211247
# Val R^2: 0.3993030848243724

# %%
coef_df = pd.DataFrame(list(lr.coef_), list(X_train.columns), columns=['coefficient'])
print(coef_df)
# Out:
#           coefficient
# Age         -0.108029
# PA           0.022348
# AB          -0.027736
# R            0.008372
# H            0.034550
# 2B           0.014141
# 3B           0.011952
# HR          -0.027256
# RBI         -0.008209
# SB          -0.001099
# CS           0.029939
# BB          -0.008674
# SO          -0.000421
# BA         -12.845726
# OBP        -15.355013
# OPS          2.049632
# OPS+         0.011134
# TB          -0.009174
# GIDP         0.002316
# HBP         -0.020763
# SH          -0.203690
# SF           0.030130
# IBB          0.044346
# curr_WAR     0.507187

# %%
print(coef_df.sort_values(by='coefficient',ascending=False))
# Out:
#           coefficient
# OPS          2.049632
# curr_WAR     0.507187
# IBB          0.044346
# H            0.034550
# SF           0.030130
# CS           0.029939
# PA           0.022348
# 2B           0.014141
# 3B           0.011952
# OPS+         0.011134
# R            0.008372
# GIDP         0.002316
# SO          -0.000421
# SB          -0.001099
# RBI         -0.008209
# BB          -0.008674
# TB          -0.009174
# HBP         -0.020763
# HR          -0.027256
# AB          -0.027736
# Age         -0.108029
# SH          -0.203690
# BA         -12.845726
# OBP        -15.355013

# %% [markdown]
# All sorts of multicollinearity problems here, including negative coefficients for obviously beneficial stats like OBP. Let's use StatsModels to look at the P>|t| values, which might come in handy in the future when we cut down to a more manageable number of variables.

# %%
import statsmodels.api as sm
model = sm.OLS(y_train, X_train)

# Fit your model to your training set
fit = model.fit()

# Print summary statistics of the model's performance
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                    WAR   R-squared (uncentered):                   0.590
# Model:                            OLS   Adj. R-squared (uncentered):              0.563
# Method:                 Least Squares   F-statistic:                              21.44
# Date:                Mon, 15 Aug 2022   Prob (F-statistic):                    6.90e-53
# Time:                        19:46:26   Log-Likelihood:                         -685.02
# No. Observations:                 365   AIC:                                      1416.
# Df Residuals:                     342   BIC:                                      1506.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
preds=lr.predict(X_val)
resids = y_val-preds
fig = plt.scatter(preds, resids)
fig.axes.set_ylabel('Residual')
fig.axes.set_xlabel('Prediction')
# Out:
# Text(0.5, 0, 'Prediction')

# %%
import scipy.stats as stats

stats.probplot(resids, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# # Model Development

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)
alphas = 10**np.linspace(-4,4,200)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_val)

# Fit a model using polynomial features
lr_poly = LinearRegression()
lr_poly.fit(X_train_poly,y_train)
lr_poly.score(X_train_poly,y_train)
# Out:
# 0.8827823232333697

# %%
lr_poly.score(X_val_poly, y_val)
# Out:
# -24.863075517245594

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_tr_scaled)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_va_scaled)

# Fit a model using polynomial features
lr_poly = LinearRegression()
lr_poly.fit(X_train_poly,y_train)
lr_poly.score(X_train_poly,y_train)
# Out:
# -5.775492073989034

# %%
lr_poly.score(X_val_poly, y_val)
# Out:
# -7.234058407554786e+18

# %%
from sklearn.linear_model import LassoCV,RidgeCV,ElasticNetCV
lassocv_model = LassoCV(alphas=alphas, cv=5, max_iter=100000)
lassocv_model.fit(X_tr_scaled, y_train)
lasso_val_r2 = lassocv_model.score(X_va_scaled, y_val)
print(lasso_val_r2)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4595747766442173, tolerance: 0.11985502739726031
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5618924248228723, tolerance: 0.12605809246575342
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.3982106141880726

# %%
ridge_model = RidgeCV(alphas=alphas, cv=5)
ridge_model.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model.score(X_va_scaled, y_val)
print(ridge_val_r2)
# Out:
# 0.4162191254109866

# %%
l1_ratios = [0.01, 0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]
ECV_model = ElasticNetCV(alphas=alphas, l1_ratio=l1_ratios, cv=5, max_iter=100000)
ECV_model.fit(X_tr_scaled, y_train)
ecv_test_r2 = ECV_model.score(X_va_scaled, y_val)
print(ecv_test_r2)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12417956001377206, tolerance: 0.11985502739726031
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.23884301278599196, tolerance: 0.11985502739726031
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3225337680235043, tolerance: 0.12605809246575342
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
coef_df = pd.DataFrame(list(lassocv_model.coef_), list(X_train.columns), columns=['coefficient'])
print(coef_df)
# Out:
#           coefficient
# Age         -0.358678
# PA           0.000000
# AB           0.000000
# R            0.000000
# H            0.000000
# 2B           0.057577
# 3B           0.021052
# HR          -0.000000
# RBI         -0.000000
# SB           0.000000
# CS           0.043375
# BB           0.053597
# SO           0.000000
# BA          -0.000000
# OBP         -0.000000
# OPS         -0.017370
# OPS+        -0.000000
# TB           0.000000
# GIDP         0.000000
# HBP         -0.000000
# SH          -0.147491
# SF           0.054721
# IBB          0.056399
# curr_WAR     0.893521

# %%
print(coef_df.sort_values(by='coefficient',ascending=False))
# Out:
#           coefficient
# curr_WAR     0.893521
# 2B           0.057577
# IBB          0.056399
# SF           0.054721
# BB           0.053597
# CS           0.043375
# 3B           0.021052
# BA          -0.000000
# HBP         -0.000000
# GIDP         0.000000
# TB           0.000000
# OPS+        -0.000000
# OBP         -0.000000
# SO           0.000000
# PA           0.000000
# SB           0.000000
# RBI         -0.000000
# HR          -0.000000
# H            0.000000
# R            0.000000
# AB           0.000000
# OPS         -0.017370
# SH          -0.147491
# Age         -0.358678

# %% [markdown]
# ## Trying with different subsets

# %%
subset_df = new_df[['Age', 'BA', 'OPS+', 'curr_WAR', 'WAR', 'Year']]
X=subset_df.drop(columns=['WAR'],axis=1)
y=subset_df['WAR']

Train = subset_df[new_df['Year'] == 2016]
Val = subset_df[new_df['Year'] == 2017]
Test = subset_df[new_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_tr_scaled)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_va_scaled)

# Fit a model using polynomial features
lr_poly = LinearRegression()
lr_poly.fit(X_train_poly,y_train)
lr_poly.score(X_val_poly, y_val)
# Out:
# 0.36724173602477705

# %%
lassocv_model = LassoCV(alphas=alphas, cv=5, max_iter=100000)
lassocv_model.fit(X_tr_scaled, y_train)
lasso_val_r2 = lassocv_model.score(X_va_scaled, y_val)
print(lasso_val_r2)
# Out:
# 0.38104601614559186

# %%
ridge_model = RidgeCV(alphas=alphas, cv=5)
ridge_model.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model.score(X_va_scaled, y_val)
print(ridge_val_r2)
# Out:
# 0.38087840675549656

# %%
l1_ratios = [0.01, 0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]
ECV_model = ElasticNetCV(alphas=alphas, l1_ratio=l1_ratios, cv=5, max_iter=100000)
ECV_model.fit(X_tr_scaled, y_train)
ecv_va_r2 = ECV_model.score(X_va_scaled, y_val)
print(ecv_va_r2)
# Out:
# 0.38104601614559186

# %%
coef_df = pd.DataFrame(list(ridge_model.coef_), list(X_train.columns), columns=['coefficient'])
print(coef_df)
# Out:
#           coefficient
# Age         -0.379860
# BA          -0.115345
# OPS+         0.012163
# curr_WAR     1.132471

# %% [markdown]
# Let's compare all of our models so far to a "baseline" model, which is simply:
#
# next season WAR = current season WAR

# %%
preds=X_val['curr_WAR']
from sklearn.metrics import r2_score
 
r2_score(preds,y_val)
# Out:
# 0.1597236426303913

# %% [markdown]
# Residual and QQ Plot for the Ridge Model above

# %%
preds=ridge_model.predict(X_va_scaled)
resids = y_val-preds
fig = plt.scatter(preds, resids)
fig.axes.set_ylabel('Residual')
fig.axes.set_xlabel('Prediction')
# Out:
# Text(0.5, 0, 'Prediction')

# %%
stats.probplot(resids, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# #### A different Subset Approach

# %%
subset_df = new_df[['Age', '2B', 'H', 'R', 'curr_WAR', 'WAR', 'Year']]
X=subset_df.drop(columns=['WAR'],axis=1)
y=subset_df['WAR']

Train = subset_df[subset_df['Year'] == 2016]
Val = subset_df[subset_df['Year'] == 2017]
Test = subset_df[subset_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_tr_scaled)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_va_scaled)

# Fit a model using polynomial features
lr_poly_2 = LinearRegression()
lr_poly_2.fit(X_train_poly,y_train)

print('Train R^2: ' + str(lr_poly_2.score(X_train_poly,y_train)))

print("val r2 " + str(lr_poly_2.score(X_val_poly, y_val)))
# Out:
# Train R^2: 0.3730341073788028
# val r2 0.3854612399571016

# %%
lassocv_model2 = LassoCV(alphas=alphas, cv=5, max_iter=100000)
lassocv_model2.fit(X_tr_scaled, y_train)
lasso_val_r2 = lassocv_model2.score(X_va_scaled, y_val)
print(lasso_val_r2)
# Out:
# 0.3970047073431474

# %%
ridge_model2 = RidgeCV(alphas=alphas, cv=5)
ridge_model2.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model2.score(X_va_scaled, y_val)
print(ridge_val_r2)
# Out:
# 0.40134504402006077

# %%
l1_ratios = [0.01, 0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]
ECV_model2 = ElasticNetCV(alphas=alphas, l1_ratio=l1_ratios, cv=5, max_iter=100000)
ECV_model2.fit(X_tr_scaled, y_train)
ecv_va_r2 = ECV_model2.score(X_va_scaled, y_val)
print(ecv_va_r2)
# Out:
# 0.3970047073431474

# %%
coef_df = pd.DataFrame(list(ridge_model2.coef_), list(X_train.columns), columns=['coefficient'])
print(coef_df)
# Out:
#           coefficient
# Age         -0.396128
# 2B           0.161074
# H           -0.055637
# R            0.152133
# curr_WAR     0.857803

# %% [markdown]
# What if we drop to just age and current WAR?

# %%
subset_df = new_df[['Age', 'curr_WAR', 'WAR', 'Year']]
X=subset_df.drop(columns=['WAR'],axis=1)
y=subset_df['WAR']

Train = subset_df[subset_df['Year'] == 2016]
Val = subset_df[subset_df['Year'] == 2017]
Test = subset_df[subset_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_tr_scaled)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_va_scaled)

# Fit a model using polynomial features
lr_poly3 = LinearRegression()
lr_poly3.fit(X_train_poly,y_train)

print('Train R^2: ' + str(lr_poly3.score(X_train_poly,y_train)))

print("val r2 " + str(lr_poly3.score(X_val_poly, y_val)))
# Out:
# Train R^2: 0.3562833437021793
# val r2 0.3827908693143003

# %%
lassocv_model3 = LassoCV(alphas=alphas, cv=5, max_iter=100000)
lassocv_model3.fit(X_tr_scaled, y_train)
lasso_val_r2 = lassocv_model3.score(X_va_scaled, y_val)
print(lasso_val_r2)
# Out:
# 0.37920747948318867

# %%
ridge_model3 = RidgeCV(alphas=alphas, cv=5)
ridge_model3.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model3.score(X_va_scaled, y_val)
print(ridge_val_r2)
# Out:
# 0.378276062174808

# %%
l1_ratios = [0.01, 0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]
ECV_model3 = ElasticNetCV(alphas=alphas, l1_ratio=l1_ratios, cv=5, max_iter=100000)
ECV_model3.fit(X_tr_scaled, y_train)
ecv_va_r2 = ECV_model3.score(X_va_scaled, y_val)
print(ecv_va_r2)
# Out:
# 0.3792060961881407

# %%
subset_df = new_df[['Age', '2B', 'H', 'R', 'curr_WAR', 'WAR', 'Year']]
X=subset_df.drop(columns=['WAR'],axis=1)
y=subset_df['WAR']

Train = subset_df[subset_df['Year'] == 2016]
Val = subset_df[subset_df['Year'] == 2017]
Test = subset_df[subset_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
ridge_model2 = RidgeCV(alphas=alphas, cv=5)
ridge_model2.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model2.score(X_va_scaled, y_val)
print(ridge_val_r2)
# Out:
# 0.40134504402006077

# %%
preds=ridge_model2.predict(X_va_scaled)
resids = y_val-preds
fig = plt.scatter(preds, resids)
fig.axes.set_ylabel('Residual')
fig.axes.set_xlabel('Prediction')
# Out:
# Text(0.5, 0, 'Prediction')

# %%
stats.probplot(resids, dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %% [markdown]
# Let's look at some of the biggest "misses" and see what might be causing these

# %%
X_inspect=X_val.copy()
X_inspect['resids']=resids
X_inspect['next season WAR'] = y_val
bottom_five = X_inspect.sort_values(by='resids').iloc[:5,:]
top_five = X_inspect.sort_values(by='resids').iloc[-5:,:]

# %%
bottom_five
# Out:
#      Age  2B    H   R  curr_WAR    resids  next season WAR
# 412   23  14  117  69       4.9 -3.695664             -0.3
# 443   31  15   98  65      -0.6 -3.452043             -3.3
# 680   23  33  159  85       5.3 -3.405718              0.5
# 693   28  21  125  78       3.9 -2.973666             -0.4
# 409   30  29  141  82       2.8 -2.907057             -0.9

# %%
for i in bottom_five.index:
    print(df.iloc[i]['Name'], df.iloc[i]['Year'])
# Out:
# Byron Buxton 2017
# Chris Davis* 2017
# Corey Seager* 2017
# Steven Souza Jr. 2017
# Jay Bruce* 2017

# %% [markdown]
# All of these players had much worse following years, with in some cases fewer games played perhaps as a combination of injuries or being benched. Buxton was an MVP candidate in 2017. Seager was an All-Star in 2017.

# %%
top_five
# Out:
#      Age  2B    H    R  curr_WAR    resids  next season WAR
# 733   25  36  170  100       3.7  4.189770              7.3
# 407   23  39  158   88       4.0  4.451703              7.9
# 429   24  23   68   39       3.2  5.026160              7.6
# 713   25  25  123   92       6.9  5.552541              9.9
# 395   24  46  166  101       6.4  6.138127             10.7

# %%
for i in top_five.index:
    print(df.iloc[i]['Name'], df.iloc[i]['Year'])
# Out:
# Christian Yelich* 2017
# Alex Bregman 2017
# Matt Chapman 2017
# Mike Trout 2017
# Mookie Betts 2017

# %% [markdown]
# Yelich was good in 2017, but MVP (and an all-star) in 2018. He had a better 2016 than 2017.
# Bregman was an all-star in 2018.
# Chapman was only a rookie in 2017.
# Trout had a relatively "down" year in 2017 compared to 2016 (when he was MVP) and 2015.
# Similar to Yelich 2017, Betts was good in 2017, just not as dominant as he was in 2016.
#
# A model that could "look back" farther would likely be more effective at predicting these types of players' performance (albeit likely not rookies).

# %%
mod_df = new_df.copy()
mod_df['high_year'] = [1 if i > 4 else 0 for i in mod_df['curr_WAR']]
X=mod_df.drop(columns=['WAR'],axis=1)
y=mod_df['WAR']

Train = mod_df[mod_df['Year'] == 2016]
Val = mod_df[mod_df['Year'] == 2017]
Test = mod_df[mod_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
lassocv_model4 = LassoCV(alphas=alphas, cv=5, max_iter=100000)
lassocv_model4.fit(X_tr_scaled, y_train)
lasso_val_r2 = lassocv_model4.score(X_va_scaled, y_val)
print(lasso_val_r2)
# Out:
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33041507999428177, tolerance: 0.12605809246575342
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.6445232366226037, tolerance: 0.12605809246575342
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.3620080122382642
# /home/user/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27595996293689495, tolerance: 0.12605809246575342
#   model = cd_fast.enet_coordinate_descent_gram(

# %%
lassocv_model.coef_
# Out:
# array([-0.37180267, -0.09379685, -0.        ,  1.12914362])

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_tr_scaled)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_va_scaled)

# Fit a model using polynomial features
lr_poly4 = LinearRegression()
lr_poly4.fit(X_train_poly,y_train)

print('Train R^2: ' + str(lr_poly4.score(X_train_poly,y_train)))

print("val r2 " + str(lr_poly4.score(X_val_poly, y_val)))
# Out:
# Train R^2: -1.572751875844682
# val r2 -50.91266475098169

# %%
ridge_model4 = RidgeCV(alphas=alphas, cv=5)
ridge_model4.fit(X_tr_scaled, y_train)
ridge_val_r4 = ridge_model4.score(X_va_scaled, y_val)
print(ridge_val_r4)
# Out:
# 0.37831341829905074

# %% [markdown]
# Let's try a smaller selection

# %%
subset_df = mod_df[['Age', 'curr_WAR', 'high_year', 'WAR', 'Year']]
X=subset_df.drop(columns=['WAR'],axis=1)
y=subset_df['WAR']

Train = subset_df[subset_df['Year'] == 2016]
Val = subset_df[subset_df['Year'] == 2017]
Test = subset_df[subset_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_val = Val.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_val = Val['WAR']
y_test = Test['WAR']

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_va_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %%
poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_tr_scaled)

# Apply polynomial transformation to val set
X_val_poly = poly.transform(X_va_scaled)

# Fit a model using polynomial features
lr_poly5 = LinearRegression()
lr_poly5.fit(X_train_poly,y_train)

print('Train R^2: ' + str(lr_poly5.score(X_train_poly,y_train)))

print("val r2 " + str(lr_poly5.score(X_val_poly, y_val)))
# Out:
# Train R^2: 0.3821192662820304
# val r2 0.3469384273801336

# %%
lassocv_model5 = LassoCV(alphas=alphas, cv=5, max_iter=100000)
lassocv_model5.fit(X_tr_scaled, y_train)
lasso_val_r2 = lassocv_model5.score(X_va_scaled, y_val)
print(lasso_val_r2)
# Out:
# 0.34234516699949147

# %%
ridge_model5 = RidgeCV(alphas=alphas, cv=5)
ridge_model5.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model5.score(X_va_scaled, y_val)
print(ridge_val_r2)
# Out:
# 0.33734178078542676

# %%
coef_df = pd.DataFrame(list(lassocv_model5.coef_), list(X_train.columns), columns=['coefficient'])
print(coef_df)
# Out:
#            coefficient
# Age          -0.385284
# curr_WAR      0.716642
# high_year     0.484590

# %% [markdown]
# Somewhat surprisingly, having a high-WAR year is a positive predictor of performance. But this is less useful than other approaches.

# %% [markdown]
# Let's train the final model on the entire Train and Val sets, and test on the Test set, which we had held out.

# %%
subset_df = new_df[['Age', '2B', 'H', 'R', 'curr_WAR', 'WAR', 'Year']]
Train = subset_df[(subset_df['Year'] == 2016) | (subset_df['Year'] == 2017)]
Test = subset_df[subset_df['Year'] == 2018]

X_train = Train.drop(columns=['WAR', 'Year'],axis=1)
X_test = Test.drop(columns=['WAR', 'Year'],axis=1)

y_train = Train['WAR']
y_test = Test['WAR']

scaler = StandardScaler()
scaler.fit(X_train)
X_tr_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
ridge_model5 = RidgeCV(alphas=alphas, cv=5)
ridge_model5.fit(X_tr_scaled, y_train)
ridge_val_r2 = ridge_model5.score(X_test_scaled, y_test)
print(ridge_val_r2)
# Out:
# 0.7560869414626896

# %%
coef_df = pd.DataFrame(list(ridge_model5.coef_), list(X_train.columns), columns=['coefficient'])
print(coef_df)
# Out:
#           coefficient
# Age         -0.402517
# 2B           0.392425
# H           -0.341045
# R            0.303447
# curr_WAR     0.850966

# %% [markdown]
# # Results
#
# This is what we expected - it's good that the test r-squared is actually a little higher than we had on Val, likely because we had more data to train on. This likely indicates we are not overfitting. Clearly, there are more opportunities for a more mature time-series analysis, but already we have a more promising model than the naive "future WAR = current WAR" baseline.
